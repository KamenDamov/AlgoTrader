# %%
import numpy as np
import pandas as pd
import math
import requests 
import matplotlib as plt
import seaborn as sns
import yfinance as yf
import pandas_datareader as web
from pandas_datareader import data
from bs4 import BeautifulSoup as bs
from scipy import stats

# %%
df = pd.read_csv("momentum_advanced_sheet")

# %%
#Get percentiles for each stock
cols = ['1y', '6m', '3m', '1m']
top90 = []
for c in cols: 
    for index, row in df.iterrows(): 
        #print(row['Ticker'])
        percentile_change = stats.percentileofscore(df[c+ ' Price Return'], df[c + ' Price Return'].loc[index])
        df[c + ' percentile'][index] = percentile_change
# Out:
# <ipython-input-22-64ee3ac6feb0>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change

# %%
df['Shares To Buy'] = 0

# %%
#Calculate HQM score
#Get the mean of all 4 percentiles 
df['HQM score'] = 0
from statistics import mean
for index, row in df.iterrows(): 
    all_periods_p = [row['1y percentile'], row['6m percentile'], row['3m percentile'], row['1m percentile']]
    df['HQM score'].iloc[index] = mean(all_periods_p)
# Out:
# <ipython-input-35-3833f90658a1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HQM score'].iloc[index] = mean(all_periods_p)

# %%
df.sort_values("HQM score", ascending=False)
# Out:
#       Unnamed: 0 Ticker    Price  1y Price Return  1y percentile  \
# 910          910    MTR  24.5000         3.716220     100.000000
# 1330        1330    TAL   8.8700         1.217500      98.907455
# 87            87    ARL  26.0000         1.253033      99.100257
# 1399        1399    TGS  10.8700         1.363044      99.357326
# 679          679    HLX   7.0800         1.132530      98.586118
# ...          ...    ...      ...              ...            ...
# 28            28   HIVE   1.5900        -0.896753       0.192802
# 529          529   FTCH   3.9600        -0.881045       0.321337
# 154          154    AUD   0.2300        -0.910506       0.128535
# 965          965    NTP   1.3300        -0.881673       0.257069
# 784          784     JE   0.0145        -0.985113       0.064267
#
#       6m Price Return  6m percentile  3m Price Return  3m percentile  \
# 910          1.350372      99.871465         0.969656      99.742931
# 1330         0.795547      99.035990         0.759921      99.164524
# 87           0.874549      99.228792         0.704918      98.843188
# 1399         1.118908      99.742931         0.593842      98.007712
# 679          1.306189      99.807198         0.903226      99.485861
# ...               ...            ...              ...            ...
# 28          -0.554622       1.413882        -0.559557       0.385604
# 529         -0.580064       1.221080        -0.511111       0.642674
# 154         -0.803419       0.128535        -0.425000       1.221080
# 965         -0.684460       0.385604        -0.684460       0.128535
# 784         -0.938298       0.064267        -0.922667       0.064267
#
#       1m Price Return  1m percentile  Shares To Buy  HQM score
# 910          0.497952      99.871465              0  99.871465
# 1330         0.676749     100.000000              0  99.276992
# 87           0.289043      99.485861              0  99.164524
# 1399         0.189278      98.714653              0  98.955656
# 679          0.130990      97.300771              0  98.794987
# ...               ...            ...            ...        ...
# 28          -0.253521       1.542416              0   0.883676
# 529         -0.500000       0.192802              0   0.594473
# 154         -0.361111       0.771208              0   0.562339
# 965         -0.408889       0.385604              0   0.289203
# 784         -0.762295       0.064267              0   0.064267
#
# [1556 rows x 13 columns]
