# %%
import numpy as np
import pandas as pd
import math
import requests 
import matplotlib as plt
import seaborn as sns
import yfinance as yf
import pandas_datareader as web
from pandas_datareader import data
from bs4 import BeautifulSoup as bs
from scipy import stats

# %%
df = pd.read_csv("momentum_advanced_sheet")

# %%
#Get percentiles for each stock
cols = ['1y', '6m', '3m', '1m']
top90 = []
for c in cols: 
    for index, row in df.iterrows(): 
        #print(row['Ticker'])
        percentile_change = stats.percentileofscore(df[c+ ' Price Return'], df[c + ' Price Return'].loc[index])
        df[c + ' percentile'][index] = percentile_change
# Out:
# <ipython-input-22-64ee3ac6feb0>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change

# %%
df['Shares To Buy'] = 0
# Out:
#       Unnamed: 0 Ticker      Price  1y Price Return  1y percentile  \
# 910          910    MTR  24.500000         3.716220     100.000000
# 221          221    BPT  12.100000         3.378976      99.935733
# 1228        1228   STNG  54.720001         3.319893      99.871465
# 127          127    ASC  14.520000         3.270588      99.807198
# 1375        1375    TDW  34.889999         2.209752      99.742931
# ...          ...    ...        ...              ...            ...
# 529          529   FTCH   3.960000        -0.881045       0.321337
# 965          965    NTP   1.330000        -0.881673       0.257069
# 28            28   HIVE   1.590000        -0.896753       0.192802
# 154          154    AUD   0.230000        -0.910506       0.128535
# 784          784     JE   0.014500        -0.985113       0.064267
#
#       6m Price Return  6m percentile  3m Price Return  3m percentile  \
# 910          1.350372      99.871465         0.969656      99.742931
# 221         -0.332221       6.362468         0.172096      67.223650
# 1228         0.578377      98.007712         0.339303      89.524422
# 127          1.074286      99.614396         0.566343      97.493573
# 1375         0.598259      98.200514         0.740150      99.035990
# ...               ...            ...              ...            ...
# 529         -0.580064       1.221080        -0.511111       0.642674
# 965         -0.684460       0.385604        -0.684460       0.128535
# 28          -0.554622       1.413882        -0.559557       0.385604
# 154         -0.803419       0.128535        -0.425000       1.221080
# 784         -0.938298       0.064267        -0.922667       0.064267
#
#       1m Price Return  1m percentile
# 910          0.497952      99.871465
# 221         -0.103039      14.974293
# 1228         0.040898      87.532134
# 127         -0.044737      40.745501
# 1375         0.153770      98.136247
# ...               ...            ...
# 529         -0.500000       0.192802
# 965         -0.408889       0.385604
# 28          -0.253521       1.542416
# 154         -0.361111       0.771208
# 784         -0.762295       0.064267
#
# [1556 rows x 11 columns]
