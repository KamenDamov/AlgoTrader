# %%
import numpy as np
import pandas as pd
import math
import requests 
import matplotlib as plt
import seaborn as sns
import yfinance as yf
import pandas_datareader as web
from pandas_datareader import data
from bs4 import BeautifulSoup as bs
from scipy import stats

# %%
df = pd.read_csv("value_invest_advanced_sheet")

# %%
#Get percentiles for each stock and a specific category
cols = ['Trailing PE ratio', 'Forward PE ratio', 'Price To Book', 'Price To Sale', 'EV/EBITDA', 'EV/GP', 'Working Capital']
top90 = []
for c in cols: 
    df[c + ' percentile'] = np.NaN
    for index, row in df.iterrows(): 
        percentile_change = stats.percentileofscore(df[c], df[c].loc[index])
        df[c + ' percentile'][index] = percentile_change
# Out:
# <ipython-input-3-99f688de1272>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change
# <ipython-input-3-99f688de1272>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change
# <ipython-input-3-99f688de1272>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change
# <ipython-input-3-99f688de1272>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change
# <ipython-input-3-99f688de1272>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change
# <ipython-input-3-99f688de1272>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change
# <ipython-input-3-99f688de1272>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c + ' percentile'][index] = percentile_change

# %%
df['RV Score'] = 0

# %%
for index, row in df.iterrows(): 
    df['RV Score'][index] = (df['Trailing PE ratio percentile'][index]\
        +df['Forward PE ratio percentile'][index]\
        +df['Price To Book percentile'][index]\
        +df['Price To Sale percentile'][index]\
        +df['EV/EBITDA percentile'][index]\
        +df['EV/GP percentile'][index]\
        +df['Working Capital percentile'][index])/7
# Out:
# <ipython-input-8-edbdf868dddd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RV Score'][index] = (df['Trailing PE ratio percentile'][index]\

# %%
df.sort_values(ascending=False, by='RV Score')
# Out:
#      Unnamed: 0 Ticker        Price  Trailing PE ratio  Forward PE ratio  \
# 858         858    TPL  2020.209961          40.928078         31.950182
# 112         112   AXON   168.543900         116.237170         63.362366
# 647         647   NVDA   142.639999          38.251540         33.095127
# 928         928   VEEV   161.119995          64.706825         35.725050
# 431         431    HEI   151.800003          60.478090         45.178574
# ..          ...    ...          ...                ...               ...
# 946         946     WD    79.910004          10.584106         10.857337
# 953         953    WPP    51.110001          15.256717               NaN
# 955         955    WMK    82.510002          18.500000               NaN
# 961         961    WHG    11.870000          69.823524               NaN
# 987         987    YUM   127.699997          28.956917         24.844358
#
#      Price To Book  Price To Sale  EV/EBITDA      EV/GP  Working Capital  \
# 858      21.594744      24.063120     26.512  35.187407         9.410483
# 112       9.739607      11.195462    173.725  21.547687         2.650978
# 647      16.489020      12.443425     41.476  20.691639         6.650288
# 928       7.334639      12.076262     46.051  17.037030         3.695600
# 431       7.957226       8.143693     36.404  24.707370         2.738993
# ..             ...            ...        ...        ...              ...
# 946       1.554246       1.925115        NaN   4.381130       177.491921
# 953       3.006471       0.815493     11.164   7.676427         0.930253
# 955       1.732421       0.493512      8.206   1.848894         1.945724
# 961       0.836092       1.476942      7.202   0.848026         5.924820
# 987            NaN       5.358492     21.467  15.201704         1.082686
#
#      Shares to buy  Trailing PE ratio percentile  Forward PE ratio percentile  \
# 858            NaN                     86.693548                    89.012097
# 112            NaN                     97.681452                    95.564516
# 647            NaN                     85.383065                    89.616935
# 928            NaN                     93.850806                    91.229839
# 431            NaN                     93.044355                    93.750000
# ..             ...                           ...                          ...
# 946            NaN                     30.342742                    34.072581
# 953            NaN                     43.951613                          NaN
# 955            NaN                     53.427419                          NaN
# 961            NaN                     94.455645                          NaN
# 987            NaN                     77.318548                    82.157258
#
#      Price To Book percentile  Price To Sale percentile  EV/EBITDA percentile  \
# 858                 93.245968                 99.495968             93.044355
# 112                 89.112903                 97.076613             97.580645
# 647                 92.641129                 97.681452             96.370968
# 928                 85.786290                 97.580645             96.774194
# 431                 86.895161                 92.741935             96.068548
# ..                        ...                       ...                   ...
# 946                 32.862903                 59.475806                   NaN
# 953                 62.802419                 32.560484             51.512097
# 955                 38.709677                 22.076613             35.584677
# 961                 14.415323                 50.504032             30.745968
# 987                       NaN                 88.407258             88.205645
#
#      EV/GP percentile  Working Capital percentile   RV Score
# 858         99.294355                   97.983871  94.110023
# 112         94.556452                   82.258065  93.404378
# 647         93.951613                   96.370968  93.145161
# 928         89.919355                   92.036290  92.453917
# 431         96.975806                   84.173387  91.949885
# ..                ...                         ...        ...
# 946         33.266129                   99.798387        NaN
# 953         58.770161                   19.858871        NaN
# 955         12.096774                   69.052419        NaN
# 961          3.830645                   95.665323        NaN
# 987         86.794355                   27.620968        NaN
#
# [992 rows x 19 columns]
